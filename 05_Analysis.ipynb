# %%
import numpy as np
import pickle
from eval_tools import getGroundTruthTimestamps
import plotly.graph_objs as go

# %% [markdown]
# # Plot Alignments

# %%
s = 1
modes = ['constant', 'random', 'continuous']
mode_id = 1
oltw_hyp_file = f"experiments/{modes[mode_id]}//OLTW/s{s}/hyp.npy"
oltw_tsm_file = f"experiments/{modes[mode_id]}/OLTW/s{s}/tsm.npy"
dtw_hyp_file = f"experiments/{modes[mode_id]}/NaivePairwiseDTW/s{s}/hyp.npy"
dtw_tsm_file = f"experiments/{modes[mode_id]}/NaivePairwiseDTW/s{s}/tsm.npy"
dtw_tsm_lag_400_file = f"experiments/{modes[mode_id]}/NaivePairwiseDTW/s{s}/tsm_lag400.npy"
noa_mono_hyp_file = f"experiments/{modes[mode_id]}/NOA-Mono/s{s}/hyp.npy"
noa_hyp_file = f"experiments/{modes[mode_id]}/NOA/s{s}/hyp.npy"

# load the hyp and tsm files
match_hyp = np.load(oltw_hyp_file)
match_tsm = np.load(oltw_tsm_file)
dtw_hyp = np.load(dtw_hyp_file)
dtw_tsm = np.load(dtw_tsm_file)
dtw_tsm_lag_400 = np.load(dtw_tsm_lag_400_file)
noa_mono_hyp = np.load(noa_mono_hyp_file)
noa_hyp = np.load(noa_hyp_file)

# load the ground truth timestamps
query_annot_file = f'scenarios/{modes[mode_id]}/s{s}/p.beats'
ref_annot_file = f'scenarios/{modes[mode_id]}/s{s}/o.beats'
scenarioInfo = f'scenarios/{modes[mode_id]}/s{s}/scenario.info'
gt = getGroundTruthTimestamps(query_annot_file, ref_annot_file, scenarioInfo)

# %%
gt = gt[0].T

# %%
# Create a figure
fig = go.Figure()
fig.update_layout(
    title='Alignment and TSMvPaths',
    xaxis_title='Query Time (s)',
    yaxis_title='Reference Time (s)',
    width=900,
    height=700
)
fig.add_trace(go.Scatter(
    x=match_hyp[0], y=match_hyp[1], mode='lines', name='OLTW Hyp'
))
fig.add_trace(go.Scatter(
    x=match_tsm[0], y=match_tsm[1], mode='lines', name='OLTW TSM'
))
fig.add_trace(go.Scatter(
    x=dtw_hyp[0], y=dtw_hyp[1], mode='lines', name='DTW Hyp'
))
fig.add_trace(go.Scatter(
    x=dtw_tsm[0], y=dtw_tsm[1], mode='lines', name='DTW TSM'
))
fig.add_trace(go.Scatter(
    x=gt[0], y=gt[1], mode='markers', name='Ground Truth'
))
fig.add_trace(go.Scatter(
    x=noa_mono_hyp[0], y=noa_mono_hyp[1], mode='lines', name='NOA-Mono Hyp'
))
fig.add_trace(go.Scatter(
    x=noa_hyp[0], y=noa_hyp[1], mode='lines', name='NOA Hyp'
))

fig.show()

# %% [markdown]
# # Plot Errors

# %%
oltw_eval_file = f"eval/{modes[mode_id]}/OLTW/lag0/errs.pkl"
oltw_tsm_eval_file = f"eval_tsm/{modes[mode_id]}/OLTW/lag400/errs.pkl"
# dtw_eval_file = f"eval/{modes[mode_id]}/NaivePairwiseDTW/lag0/errs.pkl"
# dtw_tsm_eval_file = f"eval_tsm/{modes[mode_id]}/NaivePairwiseDTW/lag0/errs.pkl"
# dtw_tsm_lag_400_eval_file = f"eval_tsm/{modes[mode_id]}/NaivePairwiseDTW/lag400/errs.pkl"

oltw_err = pickle.load(open(oltw_eval_file, 'rb'))[f's{s}']
oltw_tsm_err = pickle.load(open(oltw_tsm_eval_file, 'rb'))[f's{s}']
# dtw_err = pickle.load(open(dtw_eval_file, 'rb'))[f's{s}']
# dtw_tsm_err = pickle.load(open(dtw_tsm_eval_file, 'rb'))[f's{s}']
# dtw_tsm_lag_400_err = pickle.load(open(dtw_tsm_lag_400_eval_file, 'rb'))[f's{s}']

# %%
# plot the errors
fig = go.Figure()
fig.update_layout(
    title='Alignment and TSM Errors',
    xaxis_title='Reference Time (s)',
    yaxis_title='Error (s)',
    yaxis=dict(range=[-2, 2])
)
fig.add_trace(go.Scatter(x=np.arange(len(match_err)), y=match_err, mode='lines', name='OLTW'))
fig.add_trace(go.Scatter(x=np.arange(len(match_tsm_err)), y=match_tsm_err, mode='lines', name='OLTW TSM'))
fig.add_trace(go.Scatter(x=np.arange(len(dtw_err)), y=dtw_err, mode='lines', name='DTW'))
fig.add_trace(go.Scatter(x=np.arange(len(dtw_tsm_err)), y=dtw_tsm_err, mode='lines', name='DTW TSM'))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       2 fig = go.Figure()
#       3 fig.update_layout(
#       4     title='Alignment and TSM Errors',
#       5     xaxis_title='Reference Time (s)',
#       6     yaxis_title='Error (s)',
#       7     yaxis=dict(range=[-2, 2])
#       8 )
# ----> 9 fig.add_trace(go.Scatter(x=np.arange(len(match_err)), y=match_err, mode='lines', name='OLTW'))
#      10 fig.add_trace(go.Scatter(x=np.arange(len(match_tsm_err)), y=match_tsm_err, mode='lines', name='OLTW TSM'))
#      11 fig.add_trace(go.Scatter(x=np.arange(len(dtw_err)), y=dtw_err, mode='lines', name='DTW'))
#
# NameError: name 'match_err' is not defined

# %%
import plotly.graph_objects as go
from eval_tools import getGroundTruthTimestamps
from system_utils import get_scenario_info
import re

systems = ['NaivePairwiseDTW','NOA', 'MATCH', 'OLTW']
system_id = -1
modes = ['constant', 'random', 'continuous']
mode_id = -1
print(f"mode_id: {modes[mode_id]}")
s = 2
print(f"s: {s}")

alignment_path = np.load(f'experiments/{modes[mode_id]}/{systems[system_id]}/s{s}/hyp.npy')
tsm_path = np.load(f'experiments/{modes[mode_id]}/{systems[system_id]}/s{s}/tsm.npy')

# load the ground truth timestamps
query_annot_file = f'scenarios/{modes[mode_id]}/s{s}/p.beats'
ref_annot_file = f'scenarios/{modes[mode_id]}/s{s}/o.beats'
scenarioInfo = f'scenarios/{modes[mode_id]}/s{s}/scenario.info'
gt = getGroundTruthTimestamps(query_annot_file, ref_annot_file, scenarioInfo)
gt = gt[0].T

fig = go.Figure()
fig.update_layout(
    title='Alignment and TSMvPaths',
    xaxis_title='Query Time (s)',
    yaxis_title='Reference Time (s)',
    width=900,
    height=700
)

## OLTW Continuous
# fig.add_trace(go.Scatter(x=oltw_continuous_alignment[0], y=oltw_continuous_alignment[1], mode='lines', name='OLTW Alignment'))
# fig.add_trace(go.Scatter(x=oltw_continuous_tsm[0], y=oltw_continuous_tsm[1], mode='lines', name='OLTW TSM Path'))

## OLTW Random
# fig.add_trace(go.Scatter(x=oltw_random_alignment[0], y=oltw_random_alignment[1], mode='lines', name='OLTW Alignment'))
# fig.add_trace(go.Scatter(x=oltw_random_tsm[0], y=oltw_random_tsm[1], mode='lines', name='OLTW TSM Path'))

## NOA Constant
if mode_id == 0:
    infile = f'scenarios/{modes[mode_id]}/s{s}/scenario.info'
    scenario_info = get_scenario_info(infile)
    p_path = scenario_info['p']
    match = re.search(r"tsm([0-9]*\.?[0-9]+)", p_path)
    if match:
        tsm_factor = float(match.group(1))
        print(f"TSM Factor:{tsm_factor}")
fig.add_trace(go.Scatter(x=alignment_path[0], y=alignment_path[1], mode='lines', name=f'{systems[system_id]} {modes[mode_id]} Alignment'))
fig.add_trace(go.Scatter(x=tsm_path[0], y=tsm_path[1], mode='lines', name=f'{systems[system_id]} {modes[mode_id]} TSM Path'))
fig.add_trace(go.Scatter(
    x=gt[0], y=gt[1], mode='markers', name='Ground Truth'))
# Out:
# mode_id: continuous
# s: 2
